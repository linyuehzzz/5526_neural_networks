# %% [markdown]
# <a href="https://colab.research.google.com/github/linyuehzzz/5526_neural_networks/blob/master/rbf_svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Lab 3**
# This code trains an RBF kernel SVM to determine if a genomic sequence is an ncRNA..
# Yue Lin (lin.3326 at osu.edu)
# Created: 11/5/2020

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# #### **Set up libraries**

# %%
# !pip install libsvm
# Out:
# Collecting libsvm
#   Downloading https://files.pythonhosted.org/packages/4b/11/c7700d0cd3a21eef2d7d996256277fc640ccd4f84717c10228cb6c1567dc/libsvm-3.23.0.4.tar.gz (170kB)
#      |████████████████████████████████| 174kB 2.7MB/s
# Building wheels for collected packages: libsvm
#   Building wheel for libsvm (setup.py) ... done
#   Created wheel for libsvm: filename=libsvm-3.23.0.4-cp36-cp36m-linux_x86_64.whl size=233335 sha256=a6dfd567a825c037ab135b64cce3a1c71f0e3af7c0a7b584db5b1849611475c9
#   Stored in directory: /root/.cache/pip/wheels/5e/9e/b5/dbb033107407eec2f52b8cd24cf024a4b9ec8b62ea5aee995a
# Successfully built libsvm
# Installing collected packages: libsvm
# Successfully installed libsvm-3.23.0.4

# %%
from libsvm.svmutil import *
from sklearn.datasets import load_svmlight_file
import random
import matplotlib.pyplot as plt

# %% [markdown]
# #### **Divide datasets**

# %%
def divide_data(filename, n, m):
  # Read the entire training dataset
  with open(filename, 'r') as f:
    lines = f.read().splitlines()
    f.close()
  
  # Divide dataset
  lines = random.sample(lines, int(len(lines) * 0.5))
  _cv = [lines[i::n] for i in range(n)]
  _train = _cv[:m] + _cv[m + 1:]
  _train = [x for sublist in _train for x in sublist]
  _val = _cv[m]
  # print(_train)
  # print(_val)

  # Get y values
  train_y = [int(line.split(' ')[0]) for line in _train]
  val_y = [int(line.split(' ')[0]) for line in _val]
  # print(train_y)
  # print(val_y)

  # Get x values
  train_x = [line.split(' ')[1:] for line in _train]
  for i in range(len(train_x)):
    line = train_x[i]
    for j in range(len(line)):
      train_x[i][j] = float(train_x[i][j].split(':')[1])
  val_x = [line.split(' ')[1:] for line in _val]
  for i in range(len(val_x)):
    line = val_x[i]
    for j in range(len(line)):
      val_x[i][j] = float(val_x[i][j].split(':')[1])
  # print(train_x)
  # print(val_x)

  return train_x, train_y, val_x, val_y

# %% [markdown]
# #### **Select parameters for RBF kernel SVMs**

# %%
def rbf_svm_param(filename, c, alpha):
  acc = 0

  for i in range(5):
    # Prepare data
    train_x, train_y, val_x, val_y = divide_data(filename, 5, i)

    # Train svm
    prob = svm_problem(train_y, train_x)
    param_str = '-t 2 -c 2e' + str(c) + ' -g 2e' + str(alpha)
    print("Param: " + param_str)
    param = svm_parameter(param_str)
    m = svm_train(prob, param)

    # Test
    p_label, p_acc, p_val = svm_predict(val_y, val_x, m)
    acc += p_acc[0]

  return acc / 5

# %% [markdown]
# #### **Read training and test data**

# %%
def get_data(filename):
    data = load_svmlight_file(filename)
    return data

# %% [markdown]
# #### **Classification using RBF kernel SVMs**

# %%
def rbf_svm(train_data, c, alpha, test_data):
  # Get data
  train_x = train_data[0]
  train_y = train_data[1]
  test_x = test_data[0]
  test_y = test_data[1]

  # Train svm
  prob = svm_problem(train_y, train_x)
  param_str = '-t 2 -c 2e' + str(c) + ' -g 2e' + str(alpha)
  print("Param: " + param_str)
  param = svm_parameter(param_str)
  m = svm_train(prob, param)

  # Test
  p_label, p_acc, p_val = svm_predict(test_y, test_x, m)
  return p_acc

# %% [markdown]
# #### **Wrapper**

# %% [markdown]
# Selecting parameters for RBF kernel SVMs

# %%
# %cd "/content/gdrive/My Drive/Colab Notebooks/cse5526"

train_file = "ncRNA_s.train.txt"
acc = [[0] * 13 for i in range(13)]
for c in range(-4, 9):
  for alpha in range(-4, 9):
    p_acc = rbf_svm_param(train_file, c, alpha)
    acc[int(c+4)][int(alpha+4)] = p_acc
# Out:
# /content/gdrive/My Drive/Colab Notebooks/cse5526
# Param: -t 2 -c 2e-4 -g 2e-4
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-4
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-4
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-4
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-4
# Accuracy = 61.5% (123/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-3
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-3
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-3
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-3
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-3
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-2
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-2
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-2
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-2
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-2
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-1
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-1
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-1
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-1
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e-1
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e0
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e0
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e0
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e0
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e0
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e1
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e1
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e1
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e1
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e1
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e2
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e2
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e2
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e2
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e2
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e3
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e3
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e3
# Accuracy = 61.5% (123/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e3
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e3
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e4
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e4
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e4
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e4
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e4
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e5
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e5
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e5
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e5
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e6
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e6
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e6
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e6
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e6
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e7
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e7
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e7
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e7
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e7
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e8
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e8
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e8
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e8
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-4 -g 2e8
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-4
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-4
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-4
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-4
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-4
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-3
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-3
# Accuracy = 60% (120/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-3
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-3
# Accuracy = 75% (150/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-3
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-2
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-2
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-2
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-2
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-2
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-1
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-1
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-1
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-1
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e-1
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e0
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e0
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e0
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e0
# Accuracy = 74.5% (149/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e0
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e1
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e1
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e1
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e1
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e1
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e2
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e2
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e2
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e2
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e2
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e3
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e3
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e3
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e3
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e3
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e4
# Accuracy = 61.5% (123/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e4
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e4
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e4
# Accuracy = 60.5% (121/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e5
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e5
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e5
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e5
# Accuracy = 57% (114/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e6
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e6
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e6
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e6
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e6
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e7
# Accuracy = 61.5% (123/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e7
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e7
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e7
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e7
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e8
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e8
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e8
# Accuracy = 59% (118/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e8
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-3 -g 2e8
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-4
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-4
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-4
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-4
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-3
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-3
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-3
# Accuracy = 60.5% (121/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-3
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-3
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-2
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-2
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-2
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-2
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-2
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-1
# Accuracy = 62% (124/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-1
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-1
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-1
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e-1
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e0
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e0
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e0
# Accuracy = 62% (124/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e0
# Accuracy = 79.5% (159/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e0
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e1
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e1
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e1
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e1
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e1
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e2
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e2
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e2
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e2
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e2
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e3
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e3
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e3
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e3
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e3
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e4
# Accuracy = 74.5% (149/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e4
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e4
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e4
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e5
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e5
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e5
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e5
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e6
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e6
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e6
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e6
# Accuracy = 75% (150/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e6
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e7
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e7
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e7
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e7
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e7
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e8
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e8
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e8
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e8
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-2 -g 2e8
# Accuracy = 62% (124/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-4
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-4
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-4
# Accuracy = 59.5% (119/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-4
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-3
# Accuracy = 59% (118/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-3
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-3
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-3
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-3
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-2
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-2
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-2
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-2
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-2
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-1
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-1
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-1
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-1
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e-1
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e0
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e0
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e0
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e0
# Accuracy = 60.5% (121/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e0
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e1
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e1
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e1
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e1
# Accuracy = 81.5% (163/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e1
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e2
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e2
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e2
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e2
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e2
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e3
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e3
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e3
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e3
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e4
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e4
# Accuracy = 61.5% (123/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e4
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e4
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e4
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e5
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e5
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e5
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e5
# Accuracy = 61% (122/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e6
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e6
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e6
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e6
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e6
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e7
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e7
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e7
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e7
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e7
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e8
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e8
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e8
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e8
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e-1 -g 2e8
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-4
# Accuracy = 58% (116/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-4
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-4
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-4
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-3
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-3
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-3
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-3
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-3
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-2
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-2
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-2
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-2
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-2
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-1
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-1
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-1
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-1
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e0 -g 2e-1
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e0 -g 2e0
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e0 -g 2e0
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e0 -g 2e0
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e0 -g 2e0
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e0 -g 2e0
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e0 -g 2e1
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e0 -g 2e1
# Accuracy = 90% (180/200) (classification)
# Param: -t 2 -c 2e0 -g 2e1
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e0 -g 2e1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e0 -g 2e1
# Accuracy = 85.5% (171/200) (classification)
# Param: -t 2 -c 2e0 -g 2e2
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e0 -g 2e2
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e0 -g 2e2
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e0 -g 2e2
# Accuracy = 77% (154/200) (classification)
# Param: -t 2 -c 2e0 -g 2e2
# Accuracy = 81.5% (163/200) (classification)
# Param: -t 2 -c 2e0 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e0 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e0 -g 2e3
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e0 -g 2e3
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e0 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e0 -g 2e4
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e0 -g 2e4
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e0 -g 2e4
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e0 -g 2e4
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e0 -g 2e4
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e0 -g 2e5
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e0 -g 2e5
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e0 -g 2e5
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e0 -g 2e5
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e0 -g 2e5
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e0 -g 2e6
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e0 -g 2e6
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e0 -g 2e6
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e0 -g 2e6
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e0 -g 2e6
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e0 -g 2e7
# Accuracy = 75% (150/200) (classification)
# Param: -t 2 -c 2e0 -g 2e7
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e0 -g 2e7
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e0 -g 2e7
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e0 -g 2e7
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e0 -g 2e8
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e0 -g 2e8
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e0 -g 2e8
# Accuracy = 62% (124/200) (classification)
# Param: -t 2 -c 2e0 -g 2e8
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e0 -g 2e8
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-4
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-4
# Accuracy = 75% (150/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-4
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-4
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-4
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-3
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-3
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-3
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-3
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-2
# Accuracy = 61.5% (123/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-2
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-2
# Accuracy = 74.5% (149/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-2
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-2
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-1
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-1
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-1
# Accuracy = 96% (192/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-1
# Accuracy = 96% (192/200) (classification)
# Param: -t 2 -c 2e1 -g 2e-1
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e1 -g 2e0
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e1 -g 2e0
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e1 -g 2e0
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e1 -g 2e0
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e1 -g 2e0
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e1 -g 2e1
# Accuracy = 87.5% (175/200) (classification)
# Param: -t 2 -c 2e1 -g 2e1
# Accuracy = 88% (176/200) (classification)
# Param: -t 2 -c 2e1 -g 2e1
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e1 -g 2e1
# Accuracy = 89.5% (179/200) (classification)
# Param: -t 2 -c 2e1 -g 2e1
# Accuracy = 85% (170/200) (classification)
# Param: -t 2 -c 2e1 -g 2e2
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e1 -g 2e2
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e1 -g 2e2
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e1 -g 2e2
# Accuracy = 75% (150/200) (classification)
# Param: -t 2 -c 2e1 -g 2e2
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e1 -g 2e3
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e1 -g 2e3
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e1 -g 2e3
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e1 -g 2e3
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e1 -g 2e3
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e1 -g 2e4
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e1 -g 2e4
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e1 -g 2e4
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e1 -g 2e4
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e1 -g 2e4
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e1 -g 2e5
# Accuracy = 61.5% (123/200) (classification)
# Param: -t 2 -c 2e1 -g 2e5
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e1 -g 2e5
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e1 -g 2e5
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e1 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e1 -g 2e6
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e1 -g 2e6
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e1 -g 2e6
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e1 -g 2e6
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e1 -g 2e6
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e1 -g 2e7
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e1 -g 2e7
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e1 -g 2e7
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e1 -g 2e7
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e1 -g 2e7
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e1 -g 2e8
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e1 -g 2e8
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e1 -g 2e8
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e1 -g 2e8
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e1 -g 2e8
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-4
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-4
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-4
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-4
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-4
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-3
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-3
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-3
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-3
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-3
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-2
# Accuracy = 97% (194/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-2
# Accuracy = 96% (192/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-2
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-2
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-2
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-1
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-1
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-1
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-1
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e2 -g 2e-1
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e2 -g 2e0
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e2 -g 2e0
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e2 -g 2e0
# Accuracy = 92% (184/200) (classification)
# Param: -t 2 -c 2e2 -g 2e0
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e2 -g 2e0
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e2 -g 2e1
# Accuracy = 90% (180/200) (classification)
# Param: -t 2 -c 2e2 -g 2e1
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e2 -g 2e1
# Accuracy = 84% (168/200) (classification)
# Param: -t 2 -c 2e2 -g 2e1
# Accuracy = 85.5% (171/200) (classification)
# Param: -t 2 -c 2e2 -g 2e1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e2 -g 2e2
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e2 -g 2e2
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e2 -g 2e2
# Accuracy = 77.5% (155/200) (classification)
# Param: -t 2 -c 2e2 -g 2e2
# Accuracy = 77% (154/200) (classification)
# Param: -t 2 -c 2e2 -g 2e2
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e2 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e2 -g 2e3
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e2 -g 2e3
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e2 -g 2e3
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e2 -g 2e3
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e2 -g 2e4
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e2 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e2 -g 2e4
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e2 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e2 -g 2e4
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e2 -g 2e5
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e2 -g 2e5
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e2 -g 2e5
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e2 -g 2e5
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e2 -g 2e5
# Accuracy = 75% (150/200) (classification)
# Param: -t 2 -c 2e2 -g 2e6
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e2 -g 2e6
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e2 -g 2e6
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e2 -g 2e6
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e2 -g 2e6
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e2 -g 2e7
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e2 -g 2e7
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e2 -g 2e7
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e2 -g 2e7
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e2 -g 2e7
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e2 -g 2e8
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e2 -g 2e8
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e2 -g 2e8
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e2 -g 2e8
# Accuracy = 62% (124/200) (classification)
# Param: -t 2 -c 2e2 -g 2e8
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-4
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-4
# Accuracy = 75.5% (151/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-4
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-4
# Accuracy = 61% (122/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-4
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-3
# Accuracy = 96% (192/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-3
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-3
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-3
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-3
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-2
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-2
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-2
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-2
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-2
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-1
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-1
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-1
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-1
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e3 -g 2e-1
# Accuracy = 90.5% (181/200) (classification)
# Param: -t 2 -c 2e3 -g 2e0
# Accuracy = 92% (184/200) (classification)
# Param: -t 2 -c 2e3 -g 2e0
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e3 -g 2e0
# Accuracy = 90.5% (181/200) (classification)
# Param: -t 2 -c 2e3 -g 2e0
# Accuracy = 88.5% (177/200) (classification)
# Param: -t 2 -c 2e3 -g 2e0
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e3 -g 2e1
# Accuracy = 88% (176/200) (classification)
# Param: -t 2 -c 2e3 -g 2e1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e3 -g 2e1
# Accuracy = 88% (176/200) (classification)
# Param: -t 2 -c 2e3 -g 2e1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e3 -g 2e1
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e3 -g 2e2
# Accuracy = 76% (152/200) (classification)
# Param: -t 2 -c 2e3 -g 2e2
# Accuracy = 77% (154/200) (classification)
# Param: -t 2 -c 2e3 -g 2e2
# Accuracy = 77% (154/200) (classification)
# Param: -t 2 -c 2e3 -g 2e2
# Accuracy = 74.5% (149/200) (classification)
# Param: -t 2 -c 2e3 -g 2e2
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e3 -g 2e3
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e3 -g 2e3
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e3 -g 2e3
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e3 -g 2e3
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e3 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e3 -g 2e4
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e3 -g 2e4
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e3 -g 2e4
# Accuracy = 61% (122/200) (classification)
# Param: -t 2 -c 2e3 -g 2e4
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e3 -g 2e4
# Accuracy = 61% (122/200) (classification)
# Param: -t 2 -c 2e3 -g 2e5
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e3 -g 2e5
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e3 -g 2e5
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e3 -g 2e5
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e3 -g 2e5
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e3 -g 2e6
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e3 -g 2e6
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e3 -g 2e6
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e3 -g 2e6
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e3 -g 2e6
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e3 -g 2e7
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e3 -g 2e7
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e3 -g 2e7
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e3 -g 2e7
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e3 -g 2e7
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e3 -g 2e8
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e3 -g 2e8
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e3 -g 2e8
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e3 -g 2e8
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e3 -g 2e8
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-4
# Accuracy = 96% (192/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-4
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-4
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-4
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-4
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-3
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-3
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-3
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-3
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-3
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-2
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-2
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-2
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-2
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-2
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-1
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-1
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-1
# Accuracy = 96% (192/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-1
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e4 -g 2e-1
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e4 -g 2e0
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e4 -g 2e0
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e4 -g 2e0
# Accuracy = 90% (180/200) (classification)
# Param: -t 2 -c 2e4 -g 2e0
# Accuracy = 88.5% (177/200) (classification)
# Param: -t 2 -c 2e4 -g 2e0
# Accuracy = 90.5% (181/200) (classification)
# Param: -t 2 -c 2e4 -g 2e1
# Accuracy = 85.5% (171/200) (classification)
# Param: -t 2 -c 2e4 -g 2e1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e4 -g 2e1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e4 -g 2e1
# Accuracy = 90.5% (181/200) (classification)
# Param: -t 2 -c 2e4 -g 2e1
# Accuracy = 85% (170/200) (classification)
# Param: -t 2 -c 2e4 -g 2e2
# Accuracy = 79% (158/200) (classification)
# Param: -t 2 -c 2e4 -g 2e2
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e4 -g 2e2
# Accuracy = 75.5% (151/200) (classification)
# Param: -t 2 -c 2e4 -g 2e2
# Accuracy = 76% (152/200) (classification)
# Param: -t 2 -c 2e4 -g 2e2
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e4 -g 2e3
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e4 -g 2e3
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e4 -g 2e3
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e4 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e4 -g 2e3
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e4 -g 2e4
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e4 -g 2e4
# Accuracy = 59.5% (119/200) (classification)
# Param: -t 2 -c 2e4 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e4 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e4 -g 2e4
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e4 -g 2e5
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e4 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e4 -g 2e5
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e4 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e4 -g 2e5
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e4 -g 2e6
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e4 -g 2e6
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e4 -g 2e6
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e4 -g 2e6
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e4 -g 2e6
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e4 -g 2e7
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e4 -g 2e7
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e4 -g 2e7
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e4 -g 2e7
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e4 -g 2e7
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e4 -g 2e8
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e4 -g 2e8
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e4 -g 2e8
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e4 -g 2e8
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e4 -g 2e8
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-4
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-4
# Accuracy = 92% (184/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-4
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-4
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-4
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-3
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-3
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-3
# Accuracy = 96% (192/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-3
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-3
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-2
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-2
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-2
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-2
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-2
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-1
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-1
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-1
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-1
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e5 -g 2e-1
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e5 -g 2e0
# Accuracy = 88% (176/200) (classification)
# Param: -t 2 -c 2e5 -g 2e0
# Accuracy = 92% (184/200) (classification)
# Param: -t 2 -c 2e5 -g 2e0
# Accuracy = 82.5% (165/200) (classification)
# Param: -t 2 -c 2e5 -g 2e0
# Accuracy = 89.5% (179/200) (classification)
# Param: -t 2 -c 2e5 -g 2e0
# Accuracy = 88.5% (177/200) (classification)
# Param: -t 2 -c 2e5 -g 2e1
# Accuracy = 85.5% (171/200) (classification)
# Param: -t 2 -c 2e5 -g 2e1
# Accuracy = 86.5% (173/200) (classification)
# Param: -t 2 -c 2e5 -g 2e1
# Accuracy = 90% (180/200) (classification)
# Param: -t 2 -c 2e5 -g 2e1
# Accuracy = 86.5% (173/200) (classification)
# Param: -t 2 -c 2e5 -g 2e1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e5 -g 2e2
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e5 -g 2e2
# Accuracy = 77% (154/200) (classification)
# Param: -t 2 -c 2e5 -g 2e2
# Accuracy = 75.5% (151/200) (classification)
# Param: -t 2 -c 2e5 -g 2e2
# Accuracy = 78% (156/200) (classification)
# Param: -t 2 -c 2e5 -g 2e2
# Accuracy = 77% (154/200) (classification)
# Param: -t 2 -c 2e5 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e5 -g 2e3
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e5 -g 2e3
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e5 -g 2e3
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e5 -g 2e3
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e5 -g 2e4
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e5 -g 2e4
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e5 -g 2e4
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e5 -g 2e4
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e5 -g 2e4
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e5 -g 2e5
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e5 -g 2e5
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e5 -g 2e5
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e5 -g 2e5
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e5 -g 2e5
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e5 -g 2e6
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e5 -g 2e6
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e5 -g 2e6
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e5 -g 2e6
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e5 -g 2e6
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e5 -g 2e7
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e5 -g 2e7
# Accuracy = 74.5% (149/200) (classification)
# Param: -t 2 -c 2e5 -g 2e7
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e5 -g 2e7
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e5 -g 2e7
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e5 -g 2e8
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e5 -g 2e8
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e5 -g 2e8
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e5 -g 2e8
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e5 -g 2e8
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-4
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-4
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-4
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-4
# Accuracy = 96% (192/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-4
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-3
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-3
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-3
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-3
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-3
# Accuracy = 96.5% (193/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-2
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-2
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-2
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-2
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-2
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-1
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-1
# Accuracy = 90.5% (181/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-1
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-1
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e6 -g 2e-1
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e6 -g 2e0
# Accuracy = 85% (170/200) (classification)
# Param: -t 2 -c 2e6 -g 2e0
# Accuracy = 84.5% (169/200) (classification)
# Param: -t 2 -c 2e6 -g 2e0
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e6 -g 2e0
# Accuracy = 85% (170/200) (classification)
# Param: -t 2 -c 2e6 -g 2e0
# Accuracy = 84.5% (169/200) (classification)
# Param: -t 2 -c 2e6 -g 2e1
# Accuracy = 84.5% (169/200) (classification)
# Param: -t 2 -c 2e6 -g 2e1
# Accuracy = 85.5% (171/200) (classification)
# Param: -t 2 -c 2e6 -g 2e1
# Accuracy = 88% (176/200) (classification)
# Param: -t 2 -c 2e6 -g 2e1
# Accuracy = 86% (172/200) (classification)
# Param: -t 2 -c 2e6 -g 2e1
# Accuracy = 86% (172/200) (classification)
# Param: -t 2 -c 2e6 -g 2e2
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e6 -g 2e2
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e6 -g 2e2
# Accuracy = 78.5% (157/200) (classification)
# Param: -t 2 -c 2e6 -g 2e2
# Accuracy = 75.5% (151/200) (classification)
# Param: -t 2 -c 2e6 -g 2e2
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e6 -g 2e3
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e6 -g 2e3
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e6 -g 2e3
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e6 -g 2e3
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e6 -g 2e3
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e6 -g 2e4
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e6 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e6 -g 2e4
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e6 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e6 -g 2e4
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e6 -g 2e5
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e6 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e6 -g 2e5
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e6 -g 2e5
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e6 -g 2e5
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e6 -g 2e6
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e6 -g 2e6
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e6 -g 2e6
# Accuracy = 71% (142/200) (classification)
# Param: -t 2 -c 2e6 -g 2e6
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e6 -g 2e6
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e6 -g 2e7
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e6 -g 2e7
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e6 -g 2e7
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e6 -g 2e7
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e6 -g 2e7
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e6 -g 2e8
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e6 -g 2e8
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e6 -g 2e8
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e6 -g 2e8
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e6 -g 2e8
# Accuracy = 68% (136/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-4
# Accuracy = 92% (184/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-4
# Accuracy = 97% (194/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-4
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-4
# Accuracy = 97% (194/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-4
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-3
# Accuracy = 94.5% (189/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-3
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-3
# Accuracy = 90.5% (181/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-3
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-3
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-2
# Accuracy = 90% (180/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-2
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-2
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-2
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-2
# Accuracy = 93.5% (187/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-1
# Accuracy = 86.5% (173/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-1
# Accuracy = 88.5% (177/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-1
# Accuracy = 88.5% (177/200) (classification)
# Param: -t 2 -c 2e7 -g 2e-1
# Accuracy = 92% (184/200) (classification)
# Param: -t 2 -c 2e7 -g 2e0
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e7 -g 2e0
# Accuracy = 90.5% (181/200) (classification)
# Param: -t 2 -c 2e7 -g 2e0
# Accuracy = 88% (176/200) (classification)
# Param: -t 2 -c 2e7 -g 2e0
# Accuracy = 85% (170/200) (classification)
# Param: -t 2 -c 2e7 -g 2e0
# Accuracy = 88.5% (177/200) (classification)
# Param: -t 2 -c 2e7 -g 2e1
# Accuracy = 82.5% (165/200) (classification)
# Param: -t 2 -c 2e7 -g 2e1
# Accuracy = 87.5% (175/200) (classification)
# Param: -t 2 -c 2e7 -g 2e1
# Accuracy = 83.5% (167/200) (classification)
# Param: -t 2 -c 2e7 -g 2e1
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e7 -g 2e1
# Accuracy = 85% (170/200) (classification)
# Param: -t 2 -c 2e7 -g 2e2
# Accuracy = 72.5% (145/200) (classification)
# Param: -t 2 -c 2e7 -g 2e2
# Accuracy = 76% (152/200) (classification)
# Param: -t 2 -c 2e7 -g 2e2
# Accuracy = 75.5% (151/200) (classification)
# Param: -t 2 -c 2e7 -g 2e2
# Accuracy = 73% (146/200) (classification)
# Param: -t 2 -c 2e7 -g 2e2
# Accuracy = 77% (154/200) (classification)
# Param: -t 2 -c 2e7 -g 2e3
# Accuracy = 62% (124/200) (classification)
# Param: -t 2 -c 2e7 -g 2e3
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e7 -g 2e3
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e7 -g 2e3
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e7 -g 2e3
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e7 -g 2e4
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e7 -g 2e4
# Accuracy = 72% (144/200) (classification)
# Param: -t 2 -c 2e7 -g 2e4
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e7 -g 2e4
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e7 -g 2e4
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e7 -g 2e5
# Accuracy = 65% (130/200) (classification)
# Param: -t 2 -c 2e7 -g 2e5
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e7 -g 2e5
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e7 -g 2e5
# Accuracy = 59.5% (119/200) (classification)
# Param: -t 2 -c 2e7 -g 2e5
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e7 -g 2e6
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e7 -g 2e6
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e7 -g 2e6
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e7 -g 2e6
# Accuracy = 77% (154/200) (classification)
# Param: -t 2 -c 2e7 -g 2e6
# Accuracy = 61.5% (123/200) (classification)
# Param: -t 2 -c 2e7 -g 2e7
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e7 -g 2e7
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e7 -g 2e7
# Accuracy = 74% (148/200) (classification)
# Param: -t 2 -c 2e7 -g 2e7
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e7 -g 2e7
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e7 -g 2e8
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e7 -g 2e8
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e7 -g 2e8
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e7 -g 2e8
# Accuracy = 63% (126/200) (classification)
# Param: -t 2 -c 2e7 -g 2e8
# Accuracy = 63.5% (127/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-4
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-4
# Accuracy = 97.5% (195/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-4
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-4
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-4
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-3
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-3
# Accuracy = 95.5% (191/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-3
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-3
# Accuracy = 92.5% (185/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-3
# Accuracy = 94% (188/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-2
# Accuracy = 92% (184/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-2
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-2
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-2
# Accuracy = 91% (182/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-2
# Accuracy = 95% (190/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-1
# Accuracy = 86% (172/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-1
# Accuracy = 91.5% (183/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-1
# Accuracy = 90% (180/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-1
# Accuracy = 93% (186/200) (classification)
# Param: -t 2 -c 2e8 -g 2e-1
# Accuracy = 90% (180/200) (classification)
# Param: -t 2 -c 2e8 -g 2e0
# Accuracy = 88% (176/200) (classification)
# Param: -t 2 -c 2e8 -g 2e0
# Accuracy = 89.5% (179/200) (classification)
# Param: -t 2 -c 2e8 -g 2e0
# Accuracy = 84.5% (169/200) (classification)
# Param: -t 2 -c 2e8 -g 2e0
# Accuracy = 87% (174/200) (classification)
# Param: -t 2 -c 2e8 -g 2e0
# Accuracy = 86.5% (173/200) (classification)
# Param: -t 2 -c 2e8 -g 2e1
# Accuracy = 87.5% (175/200) (classification)
# Param: -t 2 -c 2e8 -g 2e1
# Accuracy = 89% (178/200) (classification)
# Param: -t 2 -c 2e8 -g 2e1
# Accuracy = 87.5% (175/200) (classification)
# Param: -t 2 -c 2e8 -g 2e1
# Accuracy = 89.5% (179/200) (classification)
# Param: -t 2 -c 2e8 -g 2e1
# Accuracy = 85% (170/200) (classification)
# Param: -t 2 -c 2e8 -g 2e2
# Accuracy = 73.5% (147/200) (classification)
# Param: -t 2 -c 2e8 -g 2e2
# Accuracy = 74.5% (149/200) (classification)
# Param: -t 2 -c 2e8 -g 2e2
# Accuracy = 78% (156/200) (classification)
# Param: -t 2 -c 2e8 -g 2e2
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e8 -g 2e2
# Accuracy = 75.5% (151/200) (classification)
# Param: -t 2 -c 2e8 -g 2e3
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e8 -g 2e3
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e8 -g 2e3
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e8 -g 2e3
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e8 -g 2e3
# Accuracy = 64% (128/200) (classification)
# Param: -t 2 -c 2e8 -g 2e4
# Accuracy = 71.5% (143/200) (classification)
# Param: -t 2 -c 2e8 -g 2e4
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e8 -g 2e4
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e8 -g 2e4
# Accuracy = 62.5% (125/200) (classification)
# Param: -t 2 -c 2e8 -g 2e4
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e8 -g 2e5
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e8 -g 2e5
# Accuracy = 69.5% (139/200) (classification)
# Param: -t 2 -c 2e8 -g 2e5
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e8 -g 2e5
# Accuracy = 68.5% (137/200) (classification)
# Param: -t 2 -c 2e8 -g 2e5
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e8 -g 2e6
# Accuracy = 67.5% (135/200) (classification)
# Param: -t 2 -c 2e8 -g 2e6
# Accuracy = 70.5% (141/200) (classification)
# Param: -t 2 -c 2e8 -g 2e6
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e8 -g 2e6
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e8 -g 2e6
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e8 -g 2e7
# Accuracy = 64.5% (129/200) (classification)
# Param: -t 2 -c 2e8 -g 2e7
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e8 -g 2e7
# Accuracy = 62% (124/200) (classification)
# Param: -t 2 -c 2e8 -g 2e7
# Accuracy = 67% (134/200) (classification)
# Param: -t 2 -c 2e8 -g 2e7
# Accuracy = 70% (140/200) (classification)
# Param: -t 2 -c 2e8 -g 2e8
# Accuracy = 66% (132/200) (classification)
# Param: -t 2 -c 2e8 -g 2e8
# Accuracy = 66.5% (133/200) (classification)
# Param: -t 2 -c 2e8 -g 2e8
# Accuracy = 65.5% (131/200) (classification)
# Param: -t 2 -c 2e8 -g 2e8
# Accuracy = 69% (138/200) (classification)
# Param: -t 2 -c 2e8 -g 2e8
# Accuracy = 71% (142/200) (classification)

# %% [markdown]
# Plot accuracy matrix

# %%
with open('acc_mtx.txt', 'w') as fw:
  fw.write('\n'.join(['\t'.join([str(round(cell,2)) for cell in row]) for row in acc]))

# %% [markdown]
# Read training and test data

# %%
# %cd "/content/gdrive/My Drive/Colab Notebooks/cse5526"

# Read training and test data
train_file = "ncRNA_s.train.txt"
test_file = "ncRNA_s.test.txt"

train_data = get_data(train_file)
test_data = get_data(test_file)
# Out:
# /content/gdrive/My Drive/Colab Notebooks/cse5526

# %% [markdown]
# Classification using RBF kernel SVMs

# %%
c = 6
alpha = -3

p_acc = rbf_svm(train_data, c, alpha, test_data)
print(p_acc[0])
# Out:
# Param: -t 2 -c 2e6 -g 2e-3
# Accuracy = 94.4056% (945/1001) (classification)
# 94.4055944055944
